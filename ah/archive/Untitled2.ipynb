# %%
import pandas as pd
import datetime
from selenium import webdriver
import time
import sqlite3
import schedule



def scrape_ah(ah_webpages, df_total):
    for page, category in ah_webpages:
        product = []
        size = []
        price_frac = []
        price_int = []
        discount = []
        print(page)
        driver = webdriver.Chrome(executable_path=r'/usr/local/bin/chromedriver')
        driver.get(page)

        # wait = WebDriverWait(driver, 20)
        time.sleep(5)

        child_tags = driver.find_elements_by_xpath(".//*[@class=' row collapse product__content product__content--link']")

        for i in range(len(child_tags)):
            product.append(child_tags[i].find_element_by_xpath(".//*[@class='product-description__title  -multiline']").text)
            size.append(child_tags[i].find_element_by_xpath(".//*[@class='product-description__unit-size -multiline']").text)
            price_frac.append(child_tags[i].find_element_by_xpath(".//*[@class='price__fractional']").text)
            price_int.append(child_tags[i].find_element_by_xpath(".//*[@class='price__integer']").text)
            try:
                discount.append(child_tags[i].find_element_by_xpath(".//*[@class='discount-block']").text)
            except:
                discount.append(0)
            print(category, child_tags[i].find_element_by_xpath(".//*[@class='product-description__title  -multiline']").text)

        df = pd.DataFrame({'product': product, 'size': size, 'price_frac': price_frac, 'price_int': price_int, 'discount': discount})
        time.sleep(2)
        driver.close()

        df['price'] = (df['price_int'] + '.' + df['price_frac']).astype('float')
        df = df.drop(['price_frac', 'price_int'], axis=1)
        df['date'] = datetime.datetime.now().strftime("%Y-%m-%d")
        df['category'] = category

        df_total = pd.concat([df_total, df], sort=True)
    return df_total

# %%
def main():
    df_total = pd.DataFrame({'product': [], 'size': [], 'price': [], 'date': [],'discount': [] , 'category': []})
    ah_webpages = [
              ('https://www.ah.nl/producten/aardappel-groente-fruit', 'produce'), 
              ('https://www.ah.nl/producten/vlees-kip-vis-vega', 'meats')
#               ('https://www.ah.nl/producten/kaas-vleeswaren-delicatessen', 'deli-cheese'),
#               ('https://www.ah.nl/producten/zuivel-eieren', 'dairy-eggs'),
#               ('https://www.ah.nl/producten/frisdrank-sappen-koffie-thee','drinks-coffee-tea' ),
#               ('https://www.ah.nl/producten/drogisterij-baby', 'drugstore-baby')
              ]

    DF_AH = scrape_ah(ah_webpages, df_total)
    return DF_AH
#     to_db(DF_AH)
    #return DF_AH


if __name__ == '__main__':
    df = main()
# Out:
# https://www.ah.nl/producten/aardappel-groente-fruit
# produce AH Maiskol­ven
# produce AH Ver­se he­le ana­nas
# produce AH Zoe­te ro­de punt­pa­pri­ka's
# produce AH Pa­pri­ka mix
# produce AH Mid­del­gro­te ui­en
# produce AH Ga­lia me­loen
# produce AH Cour­get­te
# produce AH Pof aard­ap­pel
# produce AH Sla­me­lan­ge ma­ïs
# produce AH Ra­dic­chio slame­lan­ge
# produce AH Avo­ca­do ee­t­rijp
# produce AH Ver­se ge­gril­de groen­te­mix
# produce AH Bal­sa­mi­co dres­sing
# produce AH Kom­kom­mer krui­den vi­nai­gret­te
# produce AH Fram­boos-bal­sa­mi­co dres­sing
# produce AH IJs­berg­sla me­lan­ge
# produce AH Fijn­ge­sne­den an­dij­vie voor­deel
# produce AH Biet­jes ge­kookt
# produce AH Bi­o­lo­gisch Ge­rasp­te biet­jes
# produce AH Cham­pig­nons voor­deel
# produce AH Ge­sne­den cham­pig­nons
# produce AH Pak­soi
# produce AH Ro­de pa­pri­ka
# produce AH Prei
# produce AH Ker­sen
# produce AH Ne­der­land­se aard­bei­en
# produce AH Snoep­groen­te to­maat
# produce AH Kom­kom­mer
# produce AH Ro­de pa­pri­ka
# produce AH Broc­co­li
# produce AH Cour­get­te
# produce AH Trosto­ma­ten
# produce AH Pa­pri­ka mix
# produce AH Cher­ry to­ma­ten
# produce AH Ker­sen
# produce Ba­na­nen zak
# produce Chi­quita Ba­na­nen
# produce AH Pit­lo­ze ro­de drui­ven
# produce AH Ne­der­land­se aard­bei­en
# produce AH Man­da­rij­nen net
# produce AH Pit­lo­ze wit­te drui­ven
# produce AH Zoe­te klei­ne ap­pel­tjes
# produce Chi­quita Ba­na­nen
# produce Chi­quita Ba­na­nen
# produce Chi­quita Mi­ni's
# produce AH Iets krui­mi­ge aard­ap­pe­len
# produce Kriel­tjes
# produce AH Ki­lo'tje iets krui­mi­ge aard­ap­pe­len
# produce AH Duop­ak schijf­jes
# produce AH Aard­ap­pe­len iets krui­mig voor­deel
# produce AH Bar­be­cue mi­ni­k­riel­tjes
# produce Cê­la­Víta Oma's op­bak aard­ap­pel­tjes
# produce Cê­la­Víta Mi­ni-kriel­tjes
# produce AH Knof­look
# produce AH Ver­se ba­si­li­cum
# produce AH Ro­de pe­per
# produce AH Bi­o­lo­gisch Gem­ber (ver­se gem­ber­wor­tel)
# produce AH Munt voor­deel
# produce AH Plat­te pe­ter­se­lie
# produce AH Ko­ri­an­der
# produce AH Bies­look
# produce AH Snoep­groen­te to­maat
# produce AH Cher­ry to­ma­ten
# produce AH Ri­vo­lo cher­ry­to­maat
# produce AH Ge­schrap­te wor­tel­tjes voor­deel
# produce AH Snoep­groen­te kom­kom­mer
# produce AH Ge­schrap­te wor­tel­tjes
# produce AH Snoep­groen­te to­ma­ten­mix
# produce AH Wor­te­len
# produce AH Vers sap si­naas­ap­pel
# produce AH Vers sap si­naas­ap­pel
# produce Dub­bel­Frisss Bron­wa­ter met fruit­sap man­go & ap­pel
# produce AH Vers groen­te­sap spi­na­zie-avo­ca­do- ap­pel
# produce AH Ver­se smoot­hie ap­pel-ba­naan-aard­bei
# produce In­no­cent Su­per smoot­hie an­ti­oxi­dant
# produce In­no­cent Su­per smoot­hie ener­gi­se
# produce AH Vers sap si­naas­ap­pel-aard­bei
# /Users/wcasey/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:46: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
# https://www.ah.nl/producten/vlees-kip-vis-vega
# meats AH BBQ Kip­sa­té
# meats AH BBQ bur­ger
# meats AH Var­kens­sa­té
# meats AH Vers plant­aar­di­ge bur­gers
# meats AH BBQ gar­na­len­spies knof­look
# meats AH Shaslik na­tu­rel
# meats AH Kip­dij­fi­let­spies Oos­ters
# meats AH Smo­key BBQ worst
# meats Vi­ve­ra Bief­stuk
# meats AH Stuk­jes als van kip
# meats AH BBQ pak­ket
# meats AH Mi­ni worst­jes
# meats AH Al­gen quinoa bur­ger
# meats AH Cham­pig­non Ita­li­aan­se bur­ger
# meats Vi­ve­ra Vis­bur­ger
# meats AH Fala­fel
# meats AH Schar­rel kip­fi­let­blok­jes
# meats AH Schar­rel kip­haas­jes na­tu­rel
# meats AH Var­kens­haas
# meats AH Schar­rel kip­fi­lethaas­jes Pro­ven­çaals
# meats AH Bi­o­lo­gisch Spek­lap
# meats AH Bi­o­lo­gisch Rib­kar­bo­na­de
# meats AH Bi­o­lo­gisch Kip­dij­fi­let
# meats AH Schar­rel fi­let­lap­jes
# meats AH Ge­rook­te zalm­fi­let
# meats Prin­ces To­nijn stuk­ken in wa­ter
# meats Jo­hn West To­nijn­stuk­ken in olijf­olie
# meats Jo­hn West To­nijn­stuk­ken in wa­ter
# meats Jo­hn West To­nijn­stuk­ken in olijf­olie
# meats Prin­ces To­nijn stuk­ken in zon­ne­bloem­olie
# meats AH Sand­wich zalm­plak­ken ge­rookt
# meats Cap Sork Ge­rook­te zalm­fi­let
# meats AH Kip­fi­let
# meats AH Kip­fi­let na­tu­rel
# meats AH Kip­blok­jes
# meats AH Kip­fi­let
# meats AH Schar­rel kip­fi­let­blok­jes
# meats AH Kro­kan­te kip­fi­let­schnit­zel
# meats AH Kip­blok­jes
# meats AH Ge­rook­te kip­fi­let
# meats AH Run­der­ge­hakt
# meats AH Ma­ger run­der­ge­hakt
# meats AH Ham­bur­gers
# meats AH Run­der­ge­hakt
# meats AH Bi­o­lo­gisch Ham­bur­ger
# meats AH Half om half ge­hakt
# meats AH Run­der­ge­hakt
# meats AH Run­der­vin­ken
# meats AH Run­der­ge­hakt
# meats AH Ma­ger run­der­ge­hakt
# meats AH Ham­bur­gers
# meats AH Run­der­ge­hakt
# meats AH Bi­o­lo­gisch Ham­bur­ger
# meats AH Run­der­ge­hakt
# meats AH Run­der­vin­ken
# meats AH Ge­krui­de run­der­chi­po­la­ta
# meats AH Half om half ge­hakt
# meats AH Spek­lap à la mi­nu­te na­tu­rel
# meats AH Ge­pa­neer­de schnit­zel
# meats AH Sla­vin­ken
# meats AH Sla­vin­ken
# meats AH Sho­ar­ma­reep­jes
# meats AH Zi­geu­ner­schnit­zel
# meats AH Spek­lap à la mi­nu­te tan­door­i
# meats AH Kal­koen­fi­let à la mi­nu­te
# meats AH Kal­koen­fi­let blok­jes
# meats AH Kal­koen­fi­let schnit­zel
# meats AH Kal­koen­fi­let
# meats Tas­te of the World Mer­gu­ez worst­jes
# meats Tas­te of the World He­le kal­koen pan­klaar

# %%
df.drop_duplicates()
# Out:
#    category        date     discount  price  \
# 0   produce  2018-06-29        BONUS   2.49
# 1   produce  2018-06-29            0   3.00
# 2   produce  2018-06-29            0   1.79
# 3   produce  2018-06-29            0   1.69
# 4   produce  2018-06-29            0   1.35
# 5   produce  2018-06-29            0   2.09
# 6   produce  2018-06-29            0   0.69
# 7   produce  2018-06-29            0   1.19
# 8   produce  2018-06-29        BONUS   1.49
# 9   produce  2018-06-29    2E GRATIS   1.29
# 10  produce  2018-06-29    2E GRATIS   2.99
# 11  produce  2018-06-29            0   2.99
# 12  produce  2018-06-29            0   1.49
# 13  produce  2018-06-29            0   1.49
# 14  produce  2018-06-29            0   1.49
# 15  produce  2018-06-29            0   0.99
# 16  produce  2018-06-29            0   1.69
# 17  produce  2018-06-29            0   2.00
# 18  produce  2018-06-29            0   2.00
# 19  produce  2018-06-29            0   1.29
# 20  produce  2018-06-29            0   1.99
# 21  produce  2018-06-29            0   1.49
# 22  produce  2018-06-29    2E GRATIS   0.99
# 23  produce  2018-06-29            0   0.55
# 24  produce  2018-06-29                3.19
# 25  produce  2018-06-29            0   3.49
# 26  produce  2018-06-29    2E GRATIS   2.99
# 27  produce  2018-06-29    2E GRATIS   0.79
# 29  produce  2018-06-29            0   0.99
# 31  produce  2018-06-29  2 VOOR 2.00   1.89
# ..      ...         ...          ...    ...
# 31    meats  2018-06-29            0   4.49
# 32    meats  2018-06-29  2 VOOR 5.00   3.00
# 33    meats  2018-06-29            0   5.00
# 34    meats  2018-06-29            0   4.00
# 35    meats  2018-06-29            0   6.75
# 37    meats  2018-06-29  2 VOOR 5.00   3.00
# 38    meats  2018-06-29            0   5.75
# 39    meats  2018-06-29            0   2.36
# 40    meats  2018-06-29            0   3.29
# 41    meats  2018-06-29            0   3.75
# 42    meats  2018-06-29  2 VOOR 4.00   2.85
# 43    meats  2018-06-29            0   1.99
# 44    meats  2018-06-29            0   2.19
# 45    meats  2018-06-29            0   2.59
# 46    meats  2018-06-29            0   5.25
# 47    meats  2018-06-29            0   2.59
# 55    meats  2018-06-29  2 VOOR 5.00   3.49
# 57    meats  2018-06-29            0   2.45
# 58    meats  2018-06-29  2 VOOR 4.00   2.55
# 59    meats  2018-06-29            0   1.90
# 60    meats  2018-06-29            0   1.59
# 61    meats  2018-06-29    2E GRATIS   2.99
# 62    meats  2018-06-29  2 VOOR 4.00   2.99
# 63    meats  2018-06-29            0   2.95
# 64    meats  2018-06-29            0   3.72
# 65    meats  2018-06-29  2 VOOR 5.00   4.00
# 66    meats  2018-06-29            0   3.07
# 67    meats  2018-06-29            0   3.06
# 68    meats  2018-06-29            0   3.96
# 69    meats  2018-06-29            0  17.98
#
#                                          product         size
# 0                                 AH Maiskol­ven      2 stuks
# 1                        AH Ver­se he­le ana­nas     per stuk
# 2               AH Zoe­te ro­de punt­pa­pri­ka's      2 stuks
# 3                               AH Pa­pri­ka mix      3 stuks
# 4                        AH Mid­del­gro­te ui­en         1 kg
# 5                              AH Ga­lia me­loen     per stuk
# 6                                 AH Cour­get­te     per stuk
# 7                             AH Pof aard­ap­pel      2 stuks
# 8                         AH Sla­me­lan­ge ma­ïs        240 g
# 9                    AH Ra­dic­chio slame­lan­ge        200 g
# 10                        AH Avo­ca­do ee­t­rijp      2 stuks
# 11             AH Ver­se ge­gril­de groen­te­mix        250 g
# 12                     AH Bal­sa­mi­co dres­sing       150 ml
# 13        AH Kom­kom­mer krui­den vi­nai­gret­te       150 ml
# 14           AH Fram­boos-bal­sa­mi­co dres­sing       150 ml
# 15                     AH IJs­berg­sla me­lan­ge        100 g
# 16       AH Fijn­ge­sne­den an­dij­vie voor­deel        500 g
# 17                          AH Biet­jes ge­kookt        500 g
# 18          AH Bi­o­lo­gisch Ge­rasp­te biet­jes        400 g
# 19                    AH Cham­pig­nons voor­deel        400 g
# 20                   AH Ge­sne­den cham­pig­nons        250 g
# 21                                    AH Pak­soi     per stuk
# 22                            AH Ro­de pa­pri­ka     per stuk
# 23                                       AH Prei     per stuk
# 24                                    AH Ker­sen        500 g
# 25                 AH Ne­der­land­se aard­bei­en        500 g
# 26                     AH Snoep­groen­te to­maat        500 g
# 27                                AH Kom­kom­mer     per stuk
# 29                                 AH Broc­co­li        500 g
# 31                              AH Trosto­ma­ten      5 stuks
# ..                                           ...          ...
# 31               Cap Sork Ge­rook­te zalm­fi­let        200 g
# 32                                 AH Kip­fi­let      2 stuks
# 33                       AH Kip­fi­let na­tu­rel        600 g
# 34                               AH Kip­blok­jes    2 x 175 g
# 35                                 AH Kip­fi­let  2 x 3 stuks
# 37           AH Kro­kan­te kip­fi­let­schnit­zel        250 g
# 38                               AH Kip­blok­jes    2 x 300 g
# 39                      AH Ge­rook­te kip­fi­let    ca. 160 g
# 40                            AH Run­der­ge­hakt        500 g
# 41                     AH Ma­ger run­der­ge­hakt        500 g
# 42                               AH Ham­bur­gers      4 stuks
# 43                            AH Run­der­ge­hakt        300 g
# 44                  AH Bi­o­lo­gisch Ham­bur­ger      2 stuks
# 45                       AH Half om half ge­hakt        500 g
# 46                            AH Run­der­ge­hakt        900 g
# 47                            AH Run­der­vin­ken      3 stuks
# 55            AH Ge­krui­de run­der­chi­po­la­ta      8 stuks
# 57           AH Spek­lap à la mi­nu­te na­tu­rel      5 stuks
# 58                   AH Ge­pa­neer­de schnit­zel      2 stuks
# 59                                AH Sla­vin­ken      3 stuks
# 60                                AH Sla­vin­ken      2 stuks
# 61                         AH Sho­ar­ma­reep­jes        500 g
# 62                      AH Zi­geu­ner­schnit­zel      2 stuks
# 63          AH Spek­lap à la mi­nu­te tan­door­i        350 g
# 64              AH Kal­koen­fi­let à la mi­nu­te    ca. 260 g
# 65                   AH Kal­koen­fi­let blok­jes        300 g
# 66                 AH Kal­koen­fi­let schnit­zel    ca. 250 g
# 67                            AH Kal­koen­fi­let    ca. 200 g
# 68       Tas­te of the World Mer­gu­ez worst­jes    ca. 330 g
# 69  Tas­te of the World He­le kal­koen pan­klaar   ca. 2400 g
#
# [131 rows x 6 columns]
